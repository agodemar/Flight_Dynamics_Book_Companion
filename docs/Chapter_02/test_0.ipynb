% %% [markdown]
% ## This is a test
%
% This is a text

% %% [markdown]
% This is my customization:
%
% \begin{equation}
% C_L = \frac{L}{\bar{q}_\infty S }
% \end{equation}

% %%
pwd
% Out:
% Starting MATLAB ...

% %% [markdown]
% ### This is another text cell
%
% Bla bla

% %%
x = linspace(0,2*pi,50);
y = sin(x);

figure(1)
plot(x,y)
xlabel(" $x$ (m)")
% Out:
% <center><img src="data:image/png;base64,..." width="561" alt="figure_0.png"></center>
