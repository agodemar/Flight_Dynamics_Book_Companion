% %% [markdown]
% # Pippo

% %% [markdown]
% ## Pippetto

% %%
pwd
% Out:
% ans = 'C:\Users\agode\Flight_Dynamics_Book_Companion'

% %% [markdown]
% ## Pluto

% %%
A = rand(4,3);
% plot a 3D bar graph
bar3(A);
